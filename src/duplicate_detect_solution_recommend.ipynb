# %%
import pandas_gbq

# %%
query = """ 
SELECT id FROM `bigquery-public-data.stackoverflow.posts_questions` limit 1000

"""

df = pandas_gbq.read_gbq(query, project_id = "bigquery-public-data")
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=262006177488-3425ks60hkk80fssi9vpohv88g6q1iqd.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fbigquery&state=ez7jRGnw2uIKQl5KQZ5gI6D8RDvYJU&prompt=consent&access_type=offline
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# File ~/Documents/projects/duplicate_ticket_detector_solution_recommender/.venv/lib/python3.13/site-packages/pandas_gbq/query.py:85, in try_query(connector, query_fn)
#      84     logger.debug("Requesting query... ")
# ---> 85     return query_fn()
#      86 except concurrent.futures.TimeoutError as ex:
#
# ...

# %%
print(df.head())
